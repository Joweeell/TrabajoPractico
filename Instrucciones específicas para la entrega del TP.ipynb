# %% [markdown]
# # Trabajo práctico 1
# ## Instrucciones específicas para la entrega del TP:
#
# **El archivo debe estar en formato Jupyter Notebook (.ipynb) y debe contener:**
# 1.	Introducción: Indicar población, muestra y cuáles son las variables escogidas para realizar análisis del ítem 1, junto con su respectiva clasificación.
# 2.	Ítem 1: Escoger 3 variables cualitativas y 3 variables cuantitativas (incluyendo mínimo una Cuantitativa Continua), y PARA CADA VARIABLE realizar:
#
# **Variables cualitativas**
# -	Tabla de frecuencia
# -	Gráfico adecuado
# -	Interpretaciones
#
# **Variables cuantitativas**
# -	Tabla de frecuencia
# -	Gráfico adecuado
# -	Interpretaciones del gráfico
# -	Medidas de tendencia central y sus interpretaciones
# -	Percentiles 25%, 50% y 75% y sus interpretaciones
# -	Medidas de dispersión
#
# 3.	Ítem 2: Investigar y responder las preguntas, realizando cálculos y/o tablas que avalen sus respuestas:
#
# a)	¿Hay áreas del conocimiento donde las carreras sean más caras? Expliquen qué criterio diseñaron para responder la pregunta.
#
# b)	¿Qué influencia tiene la edad en el tipo de institución a la que ingresan los estudiantes?
#
# c)	¿Hay carreras cuyo arancel sea sustantivamente más caro que la mayoría de los aranceles? ¿Qué explicación pueden encontrar? Consideren qué variable de la base de datos los puede ayudar y el contexto de la región que les tocó trabajar.
#
# **La presentación (ppt/canvas/otro) debe tener:**
# 1.	Portada: Nombre de los integrantes y del docente, indicar Nombre de la Región.
# 2.	Introducción: Indicar población, muestra, mencionar las 6 avriables y su clasificación.
# 3.	Ítem 1: Mostrar resúmenes de 1 variable cualitativa y 2 variables cuantitativas (interpretaciones habladas, no escritas en el ppt (no leídas)). Una diapositiva por variable.
# 4.	Ítem 2: Mostrar tablas y/o gráficos que justifiquen la respuesta para cada pregunta, respuesta hablada que sea extraída de la tabla presentada (no leída). Una diapositiva por pregunta.
#
# Con esto, habrá mínimo 7 diapositivas, considerar un máximo de 10 diapositivas (no se necesitan más).
#
# Cabe mencionar que todo lo que se presenta en el ppt, debe estar evidenciado en el excel del trabajo.
#
# Entrega del trabajo: Ambos archivos mediante la plataforma AVA en el plazo estipulado a inicio de semestre.
#
# # *Pueden abrir un nuevo archivo en Visual Studio Code, en formato Jupyter Notebook y comenzar a desarrollar su trabajo.*

# %% [markdown]
# Rúbrica:
#
# ![{CAD411C3-CDA1-4EDF-967A-86FB32836CFF}.png](attachment:{CAD411C3-CDA1-4EDF-967A-86FB32836CFF}.png)
